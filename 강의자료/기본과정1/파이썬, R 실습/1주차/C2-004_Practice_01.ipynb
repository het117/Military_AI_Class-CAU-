# %% [markdown]
# #**[C2-004] Python/R 기초 강의**
#
# #**Practice 01_Basic Python: Part I**

# %% [markdown]
# #**Quiz 1**
# 변수를 이용하여 다음 문장들을 출력하세요.
# * 변수명1: station
# * 변수값1: "김포공항", "고속터미널", "신논현"
# * 변수명2: line
# * 변수값2: 9, 7
#
#
# **출력결과:**
#
# 김포공항행 9호선 열차가 들어오고 있습니다.
#
# 고속터미널행 7호선 열차가 들어오고 있습니다.
#
# 신논현행 9호선 열차가 들어오고 있습니다.

# %%
# Quiz 1
station = ["김포공항", "고속터미널", "신논현"]
line = [9, 7]
print(f'{station[0]}행 {line[0]}호선 열차가 들어오고 있습니다.')
print(f'{station[1]}행 {line[1]}호선 열차가 들어오고 있습니다.')
print(f'{station[2]}행 {line[0]}호선 열차가 들어오고 있습니다.')

# %% [markdown]
# #**Quiz 2**
# 여러분은 인공지능 스터디 모임을 개설하였습니다.
# 매월 오프라인 3회, 온라인 1회로, 매월 4회씩 진행하기로 했습니다.
# 아래 조건을 고려하여 온라인 스터디 날짜를 자동으로 정해주는 프로그램을 작성하세요.
# * 조건 1: 날짜 선정은 랜덤으로 결정
# * 조건 2: 매월 일수는 총 28일로 가정
# * 조건 3: 매월 1~3일은 스터디 준비 일정으로 제외
#
#
# **출력결과:**
#
# 이번 달 온라인 스터디 날짜는 XX 일로 결정되었습니다.

# %%
# Quiz 2
import random
date = random.randrange(4, 29)
print(f'이번 달 온라인 스터디 날짜는 {date} 일로 결정되었습니다.')
# Out:
# 이번 달 온라인 스터디 날짜는 23 일로 결정되었습니다.

# %% [markdown]
# #**Quiz 3**
#
# 아래 규칙에 따라 웹사이트별 비밀번호를 생성하는 프로그램을 작성하세요.
#
# 예시) http://google.com
# *  규칙 1: http:// 부분 제외 -> google.com
# *  규칙 2: 남은 문자열 중 처음 등장하는 점(.) 이후 부분 제외 -> google
# *  규칙 3: 남은 문자열의 처음 세 자리 문자 + 글자 수 + 글자 내 e의 갯수 + '!'로 비밀번호 생성 -> goo + 6 + 1 + !
#
# **출력결과(예시)**
# http://google.com 의 비밀번호는 goo61! 입니다.
#
# http://naver.com 의 비밀번호는 nav51! 입니다.
#
# http://youtube.com 의 비밀번호는 you71! 입니다.
#
# http://neflix.com 의 비밀번호는 nef71! 입니다.

# %%
# Quiz 3

# %% [markdown]
# #**Quiz 4**
# 본 강의에서 Python 코딩 대회를 개최합니다.
# 참석자들 중 추첨을 통해 1명은 5만원권, 5명은 1만원권 상품권을 증정합니다.
# 아래 조건을 고려하여 경품 당첨자 추첨 프로그램을 작성하세요.
# *  조건 1: 참석자는 총 30명이고, 참석자의 아이디는 1~30이라고 가정
# *  조건 2: 무작위로 추첨하되 중복 당첨은 불가
# *  조건 3: random 모듈 내 suffle()과 sample() 함수 활용
#
# **출력결과(예시)**
#
# ==========당첨자 발표==========
#
# 5만원권 당첨자: 13
#
# 1만원권 당첨자: [2, 7, 21, 23, 30]
#
# ==========축하합니다!==========

# %%
# Quiz 4
